# %% [markdown]
# <a href="https://colab.research.google.com/github/joosk3R/jskRprac/blob/main/%ED%91%9C%EB%B3%B8%EB%A1%A0_%ED%94%84%EB%A1%9C%EC%A0%9D%ED%8A%B82.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import pandas as pd
import numpy as np
import pandas as pd
import pandas as pd
import numpy as np
import os
import seaborn as sns

import numpy as np
import pandas as pd

# %%
import pandas as pd
import numpy as np
import os

from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor

# %%
asd = pd.read_csv('/content/모집단_보조정보(공개용).csv',encoding_errors='ignore')

# %%
asd1 = asd.sort_values('논_면적')

# %%
a= asd1["논_면적"]

# %%
asd2 = asd.sort_values("밭_면적")
asd2 = asd2.reset_index()
asd2["num"] = range(0,15808,1)

# %%
a=a.reset_index()

# %%
a = a["논_면적"]

# %%
a['inedx'] = range(0,15808,1)

# %%
a
# Out:
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
#          ...
# 15803    8278
# 15804    8304
# 15805    8309
# 15806    8405
# 15807    8481
# Name: 논_면적, Length: 15808, dtype: int64

# %%
asd1 = asd1.reset_index()

# %%
asd1
# Out:
#        index  지역구분   일련번호  논_면적  밭_면적  계_면적  Unnamed: 5  Unnamed: 6  \
# 0       2703     1   2704     0  4658  4658         NaN         NaN
# 1      11089     3  11090     0  5502  5502         NaN         NaN
# 2      11080     3  11081     0  6120  6120         NaN         NaN
# 3      11079     3  11080     0  5253  5253         NaN         NaN
# 4       2997     1   2998     0  3953  3953         NaN         NaN
# ...      ...   ...    ...   ...   ...   ...         ...         ...
# 15803   3806     1   3807  8278   414  8692         NaN         NaN
# 15804    229     1    230  8304     0  8304         NaN         NaN
# 15805  15439     3  15440  8309     0  8309         NaN         NaN
# 15806   6135     2   6136  8405     0  8405         NaN         NaN
# 15807  11275     3  11276  8481    13  8494         NaN         NaN
#
#        Unnamed: 7  sort    num
# 0             NaN     0      0
# 1             NaN  4777      1
# 2             NaN  4772      2
# ...

# %%
import matplotlib.pyplot as plt
plt.scatter(x=asd1['num'],y= asd1['논_면적'],c='red', s=0.1)
plt.scatter(x=asd1['num'],y= asd1['밭_면적'],c='blue', s=1)

# %%
import matplotlib.pyplot as plt
plt.scatter(x=asd2['num'],y= asd2['논_면적'],c='red', s=1)
plt.scatter(x=asd2['num'],y= asd2['밭_면적'],c='blue', s=0.1)

# %%
plt.scatter(x=asd1['num'],y= asd1['밭_면적'],c='red', s=6)

# %%
asd1.reset_index()
asd1["num"] = range(0,15808,1)

# %%
asd.cor)
# Out:
#                 지역구분      일련번호      논_면적      밭_면적      계_면적  Unnamed: 5  \
# 지역구분        1.000000  0.937457 -0.047766  0.088122  0.083010         NaN
# 일련번호        0.937457  1.000000 -0.076384  0.111934  0.067581         NaN
# 논_면적       -0.047766 -0.076384  1.000000 -0.910132  0.363705         NaN
# 밭_면적        0.088122  0.111934 -0.910132  1.000000  0.054924         NaN
# 계_면적        0.083010  0.067581  0.363705  0.054924  1.000000         NaN
# Unnamed: 5       NaN       NaN       NaN       NaN       NaN         NaN
# Unnamed: 6       NaN       NaN       NaN       NaN       NaN         NaN
# Unnamed: 7       NaN       NaN       NaN       NaN       NaN         NaN
#
#             Unnamed: 6  Unnamed: 7
# 지역구분               NaN         NaN
# 일련번호               NaN         NaN
# 논_면적               NaN         NaN
# 밭_면적               NaN         NaN
# 계_면적               NaN         NaN
# Unnamed: 5         NaN         NaN
# Unnamed: 6         NaN         NaN
# ...

# %%
asd
# Out:
#        지역구분   일련번호  논_면적  밭_면적  계_면적  Unnamed: 5  Unnamed: 6  Unnamed: 7
# 0         1      1  2825  3957  6782         NaN         NaN         NaN
# 1         1      2  5272   364  5636         NaN         NaN         NaN
# 2         1      3     0  6581  6581         NaN         NaN         NaN
# 3         1      4  2521  2565  5086         NaN         NaN         NaN
# 4         1      5  6501   210  6711         NaN         NaN         NaN
# ...     ...    ...   ...   ...   ...         ...         ...         ...
# 15803     3  15804  2764  2282  5046         NaN         NaN         NaN
# 15804     3  15805  1933  1584  3517         NaN         NaN         NaN
# 15805     3  15806  3305  2853  6158         NaN         NaN         NaN
# 15806     3  15807  2883  3251  6134         NaN         NaN         NaN
# 15807     3  15808   961  3086  4047         NaN         NaN         NaN
#
# [15808 rows x 8 columns]

# %%
data = pd.read_csv("/content/과거_조사자료(공개용).csv")

# %%
data.corr()
# Out:
#             지역구분      표본번호       논면적       밭면적      면적_계      rice    pepper  \
# 지역구분    1.000000  0.942809 -0.046171  0.092702  0.093444 -0.082626  0.118044
# 표본번호    0.942809  1.000000 -0.077143  0.118816  0.077693 -0.108330  0.095349
# 논면적    -0.046171 -0.077143  1.000000 -0.904569  0.375014  0.957919 -0.160896
# 밭면적     0.092702  0.118816 -0.904569  1.000000  0.055987 -0.862060  0.200248
# 면적_계    0.093444  0.077693  0.375014  0.055987  1.000000  0.368896  0.058617
# rice   -0.082626 -0.108330  0.957919 -0.862060  0.368896  1.000000 -0.154034
# pepper  0.118044  0.095349 -0.160896  0.200248  0.058617 -0.154034  1.000000
# fruit   0.170174  0.190813 -0.306426  0.330377  0.000750 -0.296044 -0.026253
#
#            fruit
# 지역구분    0.170174
# 표본번호    0.190813
# 논면적    -0.306426
# 밭면적     0.330377
# 면적_계    0.000750
# rice   -0.296044
# pepper -0.026253
# fruit   1.000000

# %%
data.head()
# Out:
#    지역구분  표본번호   논면적   밭면적  면적_계  rice  pepper  fruit
# 0     1     1  5012  1230  6242  4922       0     35
# 1     1     2  5656     0  5656  5555       0      0
# 2     1     3  2516  2704  5220  2381       0    216
# 3     1     4  4782  1304  6086  3999       0    132
# 4     1     5  1128  3784  4912  1068       0    201

# %%
train_df = data
y_var = train_df.iloc[:,5:6]

# %%
y_var
# Out:
#       rice
# 0     4922
# 1     5555
# 2     2381
# 3     3999
# 4     1068
# ...    ...
# 1495     0
# 1496  1324
# 1497   795
# 1498  1821
# 1499  1642
#
# [1500 rows x 1 columns]

# %%
train_df.iloc[:,2:5]
# Out:
#        논면적   밭면적  면적_계
# 0     5012  1230  6242
# 1     5656     0  5656
# 2     2516  2704  5220
# 3     4782  1304  6086
# 4     1128  3784  4912
# ...    ...   ...   ...
# 1495     0  4548  4548
# 1496  1394  3008  4402
# 1497   855  4827  5682
# 1498  1932  3992  5924
# 1499  1728  3070  4798
#
# [1500 rows x 3 columns]

# %%
train_x, valid_x, train_y, valid_y = train_test_split(train_df.iloc[:,2:5] , y_var, test_size=0.4, random_state=1740)

# %%
regr = RandomForestRegressor(max_depth=5, random_state=1740, n_estimators=200)
regr.fit(train_x,train_y)
# Out:
# <ipython-input-32-071195bfa9b6>:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   regr.fit(train_x,train_y)
# RandomForestRegressor(max_depth=5, n_estimators=200, random_state=1740)

# %%
test_x = asd.iloc[:,2:5]

# %%
type(test_x)
# Out:
# pandas.core.frame.DataFrame

# %%
test_x.rename(columns = {"논_면적":"논면적" , "밭_면적": "밭면적", "계_면적":"면적_계"},inplace = True)

# %%
test_x
# Out:
#         논면적   밭면적  면적_계
# 0      2825  3957  6782
# 1      5272   364  5636
# 2         0  6581  6581
# 3      2521  2565  5086
# 4      6501   210  6711
# ...     ...   ...   ...
# 15803  2764  2282  5046
# 15804  1933  1584  3517
# 15805  3305  2853  6158
# 15806  2883  3251  6134
# 15807   961  3086  4047
#
# [15808 rows x 3 columns]

# %%
asd
# Out:
#        지역구분   일련번호  논_면적  밭_면적  계_면적  Unnamed: 5  Unnamed: 6  Unnamed: 7
# 0         1      1  2825  3957  6782         NaN         NaN         NaN
# 1         1      2  5272   364  5636         NaN         NaN         NaN
# 2         1      3     0  6581  6581         NaN         NaN         NaN
# 3         1      4  2521  2565  5086         NaN         NaN         NaN
# 4         1      5  6501   210  6711         NaN         NaN         NaN
# ...     ...    ...   ...   ...   ...         ...         ...         ...
# 15803     3  15804  2764  2282  5046         NaN         NaN         NaN
# 15804     3  15805  1933  1584  3517         NaN         NaN         NaN
# 15805     3  15806  3305  2853  6158         NaN         NaN         NaN
# 15806     3  15807  2883  3251  6134         NaN         NaN         NaN
# 15807     3  15808   961  3086  4047         NaN         NaN         NaN
#
# [15808 rows x 8 columns]

# %%
pred1_rice = (regr.predict(test_x))

# %%
pred1_rice
# Out:
# array([2.71414888e+03, 4.75619440e+03, 4.39065924e-02, ...,
#        2.85692886e+03, 2.71659106e+03, 7.97676715e+02])

# %%
test_x
# Out:
#         논면적   밭면적  면적_계
# 0      2825  3957  6782
# 1      5272   364  5636
# 2         0  6581  6581
# 3      2521  2565  5086
# 4      6501   210  6711
# ...     ...   ...   ...
# 15803  2764  2282  5046
# 15804  1933  1584  3517
# 15805  3305  2853  6158
# 15806  2883  3251  6134
# 15807   961  3086  4047
#
# [15808 rows x 3 columns]

# %%
y_var2  = train_df.iloc[:,6:7]

# %%
y_var2
# Out:
#       pepper
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
# ...      ...
# 1495       0
# 1496       0
# 1497       4
# 1498       0
# 1499       0
#
# [1500 rows x 1 columns]

# %%
train_x, valid_x, train_y, valid_y = train_test_split(train_df.iloc[:,2:5] , y_var2, test_size=0.4, random_state=1740)
regr1 = RandomForestRegressor(max_depth=5, random_state=1740, n_estimators=200)
regr1.fit(train_x,train_y)
# Out:
# <ipython-input-54-f66947bf0595>:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   regr1.fit(train_x,train_y)
# RandomForestRegressor(max_depth=5, n_estimators=200, random_state=1740)

# %%
train_y
# Out:
#       pepper
# 411        0
# 517        0
# 382        0
# 618        0
# 871        0
# ...      ...
# 1307       0
# 1136       0
# 1315       2
# 744        0
# 1086    3211
#
# [900 rows x 1 columns]

# %%
pred1_pepper= (regr1.predict(test_x))
pred1_pepper
# Out:
# array([310.72469192,   0.9697802 , 342.49451597, ..., 100.88162821,
#        114.99677089,  50.05077197])

# %%
y_var3=train_df.iloc[:,7:8]
train_x, valid_x, train_y, valid_y = train_test_split(train_df.iloc[:,2:5] , y_var3, test_size=0.4, random_state=1740)
regr2 = RandomForestRegressor(max_depth=5, random_state=1740, n_estimators=200)
regr2.fit(train_x,train_y)
pred2_fruit= (regr2.predict(test_x))
# Out:
# <ipython-input-57-5b86462bd83f>:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   regr2.fit(train_x,train_y)

# %%
pred2_fruit
# Out:
# array([340.35410297,  82.72985982, 374.30753553, ..., 440.72073476,
#        471.63512752, 233.05874013])

# %%
test_x["rice"] = pred1_rice
test_x["pepper"] = pred1_pepper
test_x["fruit"] = pred2_fruit

# %%
test_x
# Out:
#         논면적   밭면적  면적_계         rice      pepper       fruit
# 0      2825  3957  6782  2714.148884  310.724692  340.354103
# 1      5272   364  5636  4756.194402    0.969780   82.729860
# 2         0  6581  6581     0.043907  342.494516  374.307536
# 3      2521  2565  5086  2249.425072   42.379972  210.456088
# 4      6501   210  6711  5765.328410    0.386751  218.876345
# ...     ...   ...   ...          ...         ...         ...
# 15803  2764  2282  5046  2685.422232   46.235905  214.058688
# 15804  1933  1584  3517  1620.380653   24.236047  113.855328
# 15805  3305  2853  6158  2856.928857  100.881628  440.720735
# 15806  2883  3251  6134  2716.591063  114.996771  471.635128
# 15807   961  3086  4047   797.676715   50.050772  233.058740
#
# [15808 rows x 6 columns]

# %%
test_x.to_csv('submission.csv', index=False)
